# %%
import numpy as np
import matplotlib.pyplot as plt
import linecache
import math
import tensorflow as tf
from tensorflow.python.framework import ops
import pickle
# %matplotlib inline

# %%
# initialize mode params
num_mode=3
ny=161
nz=23
y=np.zeros((ny,1))
z=np.zeros((nz,1))
data1=np.zeros((ny,nz))
data2=np.zeros((ny,nz))
mode_data=[['' for i in range(3)] for j in range(1)]

# get mode1-3 E and H data
j=0
for i in range(3+1,3+1+ny):
    y[j,:]=linecache.getline(r'D:\Liuang\Jupyter_notebook\my_project\Mode_data\mode1_ey.txt', i).split()
    j+=1

j=0
for i in range(3+ny+2+1,3+ny+2+1+nz):
    z[j,:]=linecache.getline(r'D:\Liuang\Jupyter_notebook\my_project\Mode_data\mode1_ey.txt', i).split()
    j+=1

for k in range(num_mode):
    j=0
    for i in range(3+ny+2+nz+2+1,3+ny+2+nz+2+1+ny):
        data1[j,:]=linecache.getline(r'D:\Liuang\Jupyter_notebook\my_project\Mode_data\mode'+str(k+1)+'_ey.txt', i).split()
        j+=1  
    mode_data[0][k]=np.copy(data1.T)

# Normlize integral{|E|^2*dydz} to 1
dy=(y[-1,0]-y[0,0])/(y.shape[0]-1)
dz=(z[-1,0]-z[0,0])/(z.shape[0]-1)
norm_mode=np.zeros((1,num_mode))
for i in range(num_mode):
    norm_mode[0,i]=np.sum(mode_data[0][i]**2*dy*dz)
    mode_data[0][i]/=np.sqrt(norm_mode[0,i])

# %%
# show three Ey modes
# generate 2d grids for y and z
yy,zz=np.meshgrid(y,z)
plt.figure()
for i in range(num_mode):
    plt.subplot(num_mode, 1, i+1)
    plt.title('mode{}_ey'.format(i+1))
    plt.pcolormesh(yy,zz,mode_data[0][i])
    plt.xlabel("Y direction/micron")
    plt.ylabel("Z direction/micron")
    plt.ylim(-0.11, 0.33)
    plt.gca().set_aspect('equal', adjustable='box')
plt.tight_layout()
plt.show()

# %%
# Synthesis data set

m_base=1000

if True:
    m_all=m_base # number of all the samples

    # pert=0.05 # perturbation of intensity after field's superposition

    np.random.seed(0) # random seed(0)
    rd1=np.random.randn(3,m_base)
    np.random.seed(1) # random seed(1)
    rd2=np.random.rand(3,m_base)

    mode_comp=np.zeros((num_mode,m_all),dtype=complex)
    mode_comp[:,:m_base]=np.abs(rd1)*np.exp(1j*rd2*2*np.pi)
else:
    with open('training_data_add_1_102417.data', 'rb') as f:
        training_data_add_1 = pickle.load(f)
    with open('training_data_add_2_102417.data', 'rb') as f:
        training_data_add_2 = pickle.load(f)

    m_all=m_base+len(training_data_add_1)+len(training_data_add_2) # number of all the samples

    # pert=0.05 # perturbation of intensity after field's superposition

    np.random.seed(0) # random seed(0)
    rd1=np.random.randn(3,m_base)
    np.random.seed(1) # random seed(1)
    rd2=np.random.rand(3,m_base)

    mode_comp=np.zeros((num_mode,m_all),dtype=complex)
    mode_comp[:,:m_base]=np.abs(rd1)*np.exp(1j*rd2*2*np.pi)
    mode_comp[:,m_base:m_base+len(training_data_add_1)]=np.array(training_data_add_1).T
    mode_comp[:,m_base+len(training_data_add_1):m_base+len(training_data_add_1)+len(training_data_add_2)]=\
                                                                                    np.array(training_data_add_2).T

field_sp=[[0+1j for i in range(m_all)] for j in range(1)] # [[Ey(0),...,Ey(m_all-1)]]
mode_comp_label=np.zeros((num_mode,m_all))
for i in range(m_all):
    for j in range(num_mode):
        field_sp[0][i]+=mode_comp[j,i]*mode_data[0][j]
mode_comp_label=np.abs(mode_comp)**2/np.sum(np.abs(mode_comp)**2,axis=0)

# %%
mode_comp_label[:,132]
# Out:
# array([ 0.0961337,  0.1437371,  0.7601292])

# %%
# view specified sample
index=132
plt.figure(num=None, figsize=(8,8), dpi=80, facecolor='w', edgecolor='k')
plt.title('index_{}_|ey|'.format(index))
plt.pcolormesh(yy,zz,np.abs(field_sp[0][index])/np.max(np.abs(field_sp[0][index])))
plt.xlabel("Y direction/micron")
plt.ylabel("Z direction/micron")
plt.ylim(-0.11, 0.33)
plt.gca().set_aspect('equal', adjustable='box')
plt.colorbar(orientation='horizontal')
plt.show()

# %%
# get farfield diffraction pattern
sp_y=y.shape[0] # sampling points along y
sp_z=z.shape[0] # sampling points along z
ff_data=[]
for i in range(m_all):
    ff_data.append(np.fft.fftshift(np.fft.fft2(field_sp[0][i]))/sp_y/sp_z)

ff_i_data=['' for i in range(m_all)]
for i in range(m_all):
    ff_i_data[i]=np.abs(ff_data[i])**2

# %%
# view specified farfield pattern
sl_y=dy # sampling length(unit) along y
sl_z=dz # sampling length(unit) along z
sf_y=1/dy # sampling frequency along y
sf_z=1/dz # sampling frequency along z
f_y=np.fft.fftshift(np.fft.fftfreq(sp_y,sl_y))
f_z=np.fft.fftshift(np.fft.fftfreq(sp_z,sl_z))
index=132
plt.figure(num=None, figsize=(5,5), dpi=80, facecolor='w', edgecolor='k')
plt.pcolormesh(f_y,f_z,10*np.log10(ff_i_data[index]/np.max(ff_i_data[index])))
plt.title('Far field intensity distribution/dB')
plt.xlabel('far field y/a.u.')
plt.ylabel('far field z/a.u.')
plt.gca().set_aspect('equal', adjustable='box')
plt.colorbar()
plt.show()

# %%
ff_i_data[index].max()
# Out:
# 0.86161618658003236

# %%
temp_index=np.random.randint(m_all)
ff_i_data_eff_index_0,ff_i_data_eff_index_1=np.nonzero((ff_i_data[temp_index]/np.max(ff_i_data[temp_index]))>=1e-3)
print(ff_i_data_eff_index_0)
print(np.min(ff_i_data_eff_index_0),np.max(ff_i_data_eff_index_0))
print(ff_i_data_eff_index_1)
print(np.min(ff_i_data_eff_index_1),np.max(ff_i_data_eff_index_1))
# Out:
# [10 10 10 10 10 10 10 10 10 11 11 11 11 11 11 11 11 11 11 12 12 12 12 12 12
#  12 12]
# 10 12
# [76 77 78 79 80 81 82 83 84 76 77 78 79 80 81 82 83 84 85 76 77 79 80 81 82
#  83 84]
# 76 85

# %%
ff_i_data_eff=['' for i in range(m_all)]
for i in range(m_all):
    ff_i_data_eff[i]=ff_i_data[i][9:12,70:91]

# %%
# view specified farfield pattern
index=132
plt.figure(num=None, figsize=(5,5), dpi=80, facecolor='w', edgecolor='k')
plt.imshow((ff_i_data_eff[index]))
plt.title('Far field intensity distribution/dB')
plt.xlabel('far field y/a.u.')
plt.ylabel('far field z/a.u.')
plt.gca().set_aspect('equal', adjustable='box')
plt.colorbar()
plt.show()

# %%
np.random.seed(None)
permutation = list(np.random.permutation(m_all))
ff_i_data_eff_shuffled=np.array(ff_i_data_eff)[permutation,:,:]
ff_i_data_eff_shuffled=ff_i_data_eff_shuffled.reshape(m_all,ff_i_data_eff_shuffled.shape[1],
                                                      ff_i_data_eff_shuffled.shape[2],1)
mode_comp_label_shuffled=mode_comp_label[:,permutation]

# %%
X_train = -np.log10(ff_i_data_eff_shuffled[:800,:,:,:])
Y_train = mode_comp_label_shuffled[:,:800].T
X_test = -np.log10(ff_i_data_eff_shuffled[800:,:,:,:])
Y_test = mode_comp_label_shuffled[:,800:].T

# %%
def weight_variable(shape):
  initial = tf.truncated_normal(shape, stddev=0.1)
  return tf.Variable(initial)

def bias_variable(shape):
  initial = tf.constant(0.1, shape=shape)
  return tf.Variable(initial)

# %%
def conv2d(x, W):
  return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')

def max_pool_2x2(x):
  return tf.nn.max_pool(x, ksize=[1, 2, 2, 1],
                        strides=[1, 2, 2, 1], padding='SAME')

# %%
def build_graph(learning_rate):

    m = X_train.shape[0]
    
    x = tf.placeholder(tf.float32, shape=[None, X_train.shape[1],X_train.shape[2],1])
    y_ = tf.placeholder(tf.float32, shape=[None, Y_train.shape[-1]])
    
    with tf.name_scope('conv1'):
        W_conv1 = weight_variable([3, 3, 1, 16]) # [filter_height, filter_width, in_channels, out_channels]
        b_conv1 = bias_variable([16])
        h_conv1 = tf.nn.relu(conv2d(x, W_conv1) + b_conv1) # [batch, 3, 21, 16]
        h_pool1 = max_pool_2x2(h_conv1) # [batch, 2, 11, 16]
    
    with tf.name_scope('conv2'):
        W_conv2 = weight_variable([3, 3, 16, 32])
        b_conv2 = bias_variable([32])
        h_conv2 = tf.nn.relu(conv2d(h_pool1, W_conv2) + b_conv2) # [batch, 2, 11, 32]
        h_pool2 = max_pool_2x2(h_conv2) # [batch, 1, 6, 32]
        h_pool2_flat = tf.reshape(h_pool2, [-1, h_pool2.shape[1]*h_pool2.shape[2]*h_pool2.shape[3]])
    
    with tf.name_scope('fc1'):
        W_fc1 = weight_variable([np.int(h_pool2_flat.shape[-1]), 64])
        b_fc1 = bias_variable([64])
        h_fc1 = tf.nn.relu(tf.matmul(h_pool2_flat, W_fc1) + b_fc1)
        # dropout
        keep_prob = tf.placeholder(tf.float32)
        h_fc1_drop = tf.nn.dropout(h_fc1, keep_prob)
    with tf.name_scope('fc2'):
        W_fc2 = weight_variable([64, 3])
        b_fc2 = bias_variable([3])
        y_conv = tf.matmul(h_fc1_drop, W_fc2) + b_fc2
        y = tf.nn.softmax(y_conv)
    cost = tf.reduce_mean(tf.reduce_sum((y-y_)**2,axis=-1))
    optimizer = tf.train.AdamOptimizer(learning_rate).minimize(cost)
    return keep_prob, x, y_, y, cost, optimizer

# %%
def random_mini_batches(X, Y, mini_batch_size = 64):
    
    m = X.shape[0]                  # number of training examples
    mini_batches = []
    np.random.seed(None)
    
    # Step 1: Shuffle (X, Y)
    permutation = list(np.random.permutation(m))
    shuffled_X = X[permutation,:,:]
    shuffled_Y = Y[permutation,:]
    
    # Step 2: Partition (shuffled_X, shuffled_Y). Minus the end case.
    num_complete_minibatches = math.floor(m/mini_batch_size) # number of mini batches of size mini_batch_size in your partitionning
    for k in range(0, num_complete_minibatches):
        mini_batch_X = shuffled_X[k * mini_batch_size : k * mini_batch_size + mini_batch_size, :, :]
        mini_batch_Y = shuffled_Y[k * mini_batch_size : k * mini_batch_size + mini_batch_size, :]
        mini_batch = (mini_batch_X, mini_batch_Y)
        mini_batches.append(mini_batch)
    
    # Handling the end case (last mini-batch < mini_batch_size)
    if m % mini_batch_size != 0:
        mini_batch_X = shuffled_X[num_complete_minibatches * mini_batch_size : m, :, :]
        mini_batch_Y = shuffled_Y[num_complete_minibatches * mini_batch_size : m, :]
        mini_batch = (mini_batch_X, mini_batch_Y)
        mini_batches.append(mini_batch)
    
    return mini_batches

# %%
def model(X_train, Y_train, X_test, Y_test, learning_rate = 1e-4,
          num_epochs = 1500, minibatch_size = 32, keep_prob_value = 1, print_cost = True, index = 0):
    
    m = X_train.shape[0]
    
    tf.reset_default_graph()
    
    keep_prob, x, y_, y, cost, optimizer = build_graph(learning_rate)
    
    costs = []
    
    init = tf.global_variables_initializer()

    with tf.Session() as sess:
        
        # summary_writer = tf.summary.FileWriter('.\mc_regr_cnn\graph', sess.graph)
        
        sess.run(init)
        
        # Do the training loop
        for epoch in range(num_epochs):

            epoch_cost = 0.                       # Defines a cost related to an epoch
            num_minibatches = int(m / minibatch_size) # number of minibatches of size minibatch_size in the train set
            minibatches = random_mini_batches(X_train, Y_train, minibatch_size)

            for minibatch in minibatches:

                # Select a minibatch
                (minibatch_X, minibatch_Y) = minibatch
                
                _ , minibatch_cost = sess.run([optimizer, cost], feed_dict={keep_prob: keep_prob_value, x: minibatch_X, y_: minibatch_Y})
                
                epoch_cost += minibatch_cost / num_minibatches

            # Print the cost every epoch
            if print_cost == True and epoch % 100 == 0:
                print ("Cost after epoch %i: %f" % (epoch, epoch_cost))
                print ("Train mean square error:", sess.run(cost,feed_dict={keep_prob: 1, x: X_train, y_: Y_train}))
                print ("Test mean square error:", sess.run(cost,feed_dict={keep_prob: 1, x: X_test, y_: Y_test}))
            if print_cost == True and epoch % 10 == 0:
                costs.append(epoch_cost)  
        # plot the cost
        plt.plot(np.squeeze(costs))
        plt.ylabel('cost')
        plt.xlabel('iterations (per tens)')
        plt.title("Learning rate =" + str(learning_rate))
        plt.show()
        saver = tf.train.Saver()
        saved_model = saver.save(sess, '.\mc_regr_cnn\model\model_'+np.str(index))
        print("Trained model has been saved.")
        print ("Train mean square error:", sess.run(cost,feed_dict={keep_prob: 1, x: X_train, y_: Y_train}))
        print ("Test mean square error:", sess.run(cost,feed_dict={keep_prob: 1, x: X_test, y_: Y_test}))
        return costs

# %%
# index: None, learning_rate = 1e-4, num_epochs = 20000, minibatch_size = 16, keep_prob_value=0.9
# index: 1,    learning_rate = 1e-4, num_epochs = 20000, minibatch_size = 16, keep_prob_value=0.8
# index: 2,    learning_rate = 1e-4, num_epochs = 20000, minibatch_size = 16, keep_prob_value=0.7
## kernel's shape is changed to 3x3 from here
# index: 3,    learning_rate = 1e-4, num_epochs = 20000, minibatch_size = 16, keep_prob_value=0.9

# %%
costs=model(X_train, Y_train, X_test, Y_test, learning_rate = 1e-4, num_epochs = 20000, minibatch_size = 16, keep_prob_value=0.9, print_cost = True, index = 3)
# Out:
# Cost after epoch 0: 0.270616
# Train mean square error: 0.262335
# Test mean square error: 0.271103
# Cost after epoch 100: 0.009586
# Train mean square error: 0.00644421
# Test mean square error: 0.00787454
# Cost after epoch 200: 0.004538
# Train mean square error: 0.00373052
# Test mean square error: 0.00470595
# Cost after epoch 300: 0.003321
# Train mean square error: 0.0016931
# Test mean square error: 0.0023839
# Cost after epoch 400: 0.002696
# Train mean square error: 0.00114913
# Test mean square error: 0.00162513
# Cost after epoch 500: 0.002281
# Train mean square error: 0.00101831
# Test mean square error: 0.00142136
# Cost after epoch 600: 0.001922
# Train mean square error: 0.000929812
# Test mean square error: 0.00131121
# Cost after epoch 700: 0.001651
# Train mean square error: 0.000617684
# Test mean square error: 0.00109387
# Cost after epoch 800: 0.001489
# Train mean square error: 0.000676182
# Test mean square error: 0.00117107
# Cost after epoch 900: 0.001677
# Train mean square error: 0.000516036
# Test mean square error: 0.00107946
# Cost after epoch 1000: 0.001431
# Train mean square error: 0.000607386
# Test mean square error: 0.00109601
# Cost after epoch 1100: 0.001373
# Train mean square error: 0.000416819
# Test mean square error: 0.00087217
# Cost after epoch 1200: 0.001330
# Train mean square error: 0.000528076
# Test mean square error: 0.00109045
# Cost after epoch 1300: 0.001282
# Train mean square error: 0.000397346
# Test mean square error: 0.000923694
# Cost after epoch 1400: 0.001200
# Train mean square error: 0.000334486
# Test mean square error: 0.000808116
# Cost after epoch 1500: 0.001392
# Train mean square error: 0.000624898
# Test mean square error: 0.0012358
# Cost after epoch 1600: 0.001263
# Train mean square error: 0.000373333
# Test mean square error: 0.000891721
# Cost after epoch 1700: 0.001123
# Train mean square error: 0.000277226
# Test mean square error: 0.000797293
# Cost after epoch 1800: 0.001171
# Train mean square error: 0.000285304
# Test mean square error: 0.00086629
# Cost after epoch 1900: 0.001300
# Train mean square error: 0.000374843
# Test mean square error: 0.000939771
# Cost after epoch 2000: 0.001157
# Train mean square error: 0.00032398
# Test mean square error: 0.000848274
# Cost after epoch 2100: 0.001202
# Train mean square error: 0.000338155
# Test mean square error: 0.000887074
# Cost after epoch 2200: 0.001121
# Train mean square error: 0.000557699
# Test mean square error: 0.000924358
# Cost after epoch 2300: 0.001115
# Train mean square error: 0.000247786
# Test mean square error: 0.000740641
# Cost after epoch 2400: 0.001095
# Train mean square error: 0.000275739
# Test mean square error: 0.000795192
# Cost after epoch 2500: 0.001027
# Train mean square error: 0.000265666
# Test mean square error: 0.000813965
# Cost after epoch 2600: 0.001033
# Train mean square error: 0.000215265
# Test mean square error: 0.000813217
# Cost after epoch 2700: 0.000967
# Train mean square error: 0.000266596
# Test mean square error: 0.000753271
# Cost after epoch 2800: 0.001011
# Train mean square error: 0.000172747
# Test mean square error: 0.000722049
# Cost after epoch 2900: 0.001159
# Train mean square error: 0.000223564
# Test mean square error: 0.000766342
# Cost after epoch 3000: 0.001050
# Train mean square error: 0.000279777
# Test mean square error: 0.000794292
# Cost after epoch 3100: 0.001111
# Train mean square error: 0.000229108
# Test mean square error: 0.000711478
# Cost after epoch 3200: 0.001052
# Train mean square error: 0.000231594
# Test mean square error: 0.000712153
# Cost after epoch 3300: 0.001112
# Train mean square error: 0.000234293
# Test mean square error: 0.000719794
# Cost after epoch 3400: 0.001090
# Train mean square error: 0.000203959
# Test mean square error: 0.000700624
# Cost after epoch 3500: 0.001047
# Train mean square error: 0.000177357
# Test mean square error: 0.000705434
# Cost after epoch 3600: 0.000911
# Train mean square error: 0.000234667
# Test mean square error: 0.000758197
# Cost after epoch 3700: 0.000981
# Train mean square error: 0.000294354
# Test mean square error: 0.000849756
# Cost after epoch 3800: 0.000989
# Train mean square error: 0.000156928
# Test mean square error: 0.000632118
# Cost after epoch 3900: 0.000969
# Train mean square error: 0.000214513
# Test mean square error: 0.000694119
# Cost after epoch 4000: 0.000985
# Train mean square error: 0.000228621
# Test mean square error: 0.000796121
# Cost after epoch 4100: 0.001077
# Train mean square error: 0.000261361
# Test mean square error: 0.000835657
# Cost after epoch 4200: 0.001007
# Train mean square error: 0.000284197
# Test mean square error: 0.000846228
# Cost after epoch 4300: 0.001048
# Train mean square error: 0.000265176
# Test mean square error: 0.000836766
# Cost after epoch 4400: 0.000953
# Train mean square error: 0.000177043
# Test mean square error: 0.000753226
# Cost after epoch 4500: 0.001074
# Train mean square error: 0.000424624
# Test mean square error: 0.000928356
# Cost after epoch 4600: 0.000926
# Train mean square error: 0.000203759
# Test mean square error: 0.000684436
# Cost after epoch 4700: 0.000939
# Train mean square error: 0.000204239
# Test mean square error: 0.000739373
# Cost after epoch 4800: 0.000921
# Train mean square error: 0.000165213
# Test mean square error: 0.000669876
# Cost after epoch 4900: 0.001000
# Train mean square error: 0.000163039
# Test mean square error: 0.000706889
# Cost after epoch 5000: 0.000942
# Train mean square error: 0.000120952
# Test mean square error: 0.000656845
# Cost after epoch 5100: 0.000913
# Train mean square error: 0.00019893
# Test mean square error: 0.000732663
# Cost after epoch 5200: 0.001006
# Train mean square error: 0.000119319
# Test mean square error: 0.000619322
# Cost after epoch 5300: 0.000934
# Train mean square error: 0.000220401
# Test mean square error: 0.00081802
# Cost after epoch 5400: 0.001014
# Train mean square error: 0.000141842
# Test mean square error: 0.000651067
# Cost after epoch 5500: 0.000780
# Train mean square error: 0.000163708
# Test mean square error: 0.000636393
# Cost after epoch 5600: 0.000888
# Train mean square error: 0.000149088
# Test mean square error: 0.000658753
# Cost after epoch 5700: 0.000882
# Train mean square error: 0.000293993
# Test mean square error: 0.000818314
# Cost after epoch 5800: 0.000939
# Train mean square error: 0.000184048
# Test mean square error: 0.00082092
# Cost after epoch 5900: 0.000936
# Train mean square error: 0.00012681
# Test mean square error: 0.00070363
# Cost after epoch 6000: 0.000934
# Train mean square error: 0.000104861
# Test mean square error: 0.000594957
# Cost after epoch 6100: 0.000884
# Train mean square error: 0.000104782
# Test mean square error: 0.000610945
# Cost after epoch 6200: 0.000904
# Train mean square error: 0.000157462
# Test mean square error: 0.000656929
# Cost after epoch 6300: 0.000912
# Train mean square error: 0.000288964
# Test mean square error: 0.000821049
# Cost after epoch 6400: 0.000892
# Train mean square error: 0.000501125
# Test mean square error: 0.000985429
# Cost after epoch 6500: 0.000912
# Train mean square error: 0.000115001
# Test mean square error: 0.000651901
# Cost after epoch 6600: 0.000886
# Train mean square error: 0.000112705
# Test mean square error: 0.000601959
# Cost after epoch 6700: 0.000974
# Train mean square error: 0.000213559
# Test mean square error: 0.000733305
# Cost after epoch 6800: 0.000838
# Train mean square error: 0.000143744
# Test mean square error: 0.000701816
# Cost after epoch 6900: 0.000874
# Train mean square error: 0.000105023
# Test mean square error: 0.000654868
# Cost after epoch 7000: 0.000813
# Train mean square error: 0.000171579
# Test mean square error: 0.00076988
# Cost after epoch 7100: 0.000786
# Train mean square error: 0.000136498
# Test mean square error: 0.000633812
# Cost after epoch 7200: 0.000863
# Train mean square error: 0.000206828
# Test mean square error: 0.000746338
# Cost after epoch 7300: 0.000815
# Train mean square error: 0.00012853
# Test mean square error: 0.000673465
# Cost after epoch 7400: 0.000883
# Train mean square error: 0.000131542
# Test mean square error: 0.000617975
# Cost after epoch 7500: 0.000785
# Train mean square error: 9.99381e-05
# Test mean square error: 0.000699404
# Cost after epoch 7600: 0.000844
# Train mean square error: 0.000151798
# Test mean square error: 0.000694035
# Cost after epoch 7700: 0.000809
# Train mean square error: 0.000121233
# Test mean square error: 0.000684417
# Cost after epoch 7800: 0.000963
# Train mean square error: 0.000153107
# Test mean square error: 0.000698887
# Cost after epoch 7900: 0.000814
# Train mean square error: 0.000239803
# Test mean square error: 0.000803177
# Cost after epoch 8000: 0.000917
# Train mean square error: 9.49838e-05
# Test mean square error: 0.00065253
# Cost after epoch 8100: 0.000807
# Train mean square error: 0.000155306
# Test mean square error: 0.000720482
# Cost after epoch 8200: 0.000886
# Train mean square error: 0.000111389
# Test mean square error: 0.000656557
# Cost after epoch 8300: 0.000747
# Train mean square error: 9.44235e-05
# Test mean square error: 0.000651356
# Cost after epoch 8400: 0.000781
# Train mean square error: 0.000101258
# Test mean square error: 0.000671274
# Cost after epoch 8500: 0.000763
# Train mean square error: 0.000200809
# Test mean square error: 0.000738815
# Cost after epoch 8600: 0.000850
# Train mean square error: 0.00017392
# Test mean square error: 0.000684152
# Cost after epoch 8700: 0.000753
# Train mean square error: 8.98278e-05
# Test mean square error: 0.000699637
# Cost after epoch 8800: 0.000852
# Train mean square error: 0.000140776
# Test mean square error: 0.000703227
# Cost after epoch 8900: 0.000782
# Train mean square error: 9.43675e-05
# Test mean square error: 0.000645606
# Cost after epoch 9000: 0.000858
# Train mean square error: 0.00017067
# Test mean square error: 0.000745088
# Cost after epoch 9100: 0.000780
# Train mean square error: 0.000162869
# Test mean square error: 0.000729142
# Cost after epoch 9200: 0.000713
# Train mean square error: 0.000115412
# Test mean square error: 0.000674792
# Cost after epoch 9300: 0.000721
# Train mean square error: 9.27652e-05
# Test mean square error: 0.000636726
# Cost after epoch 9400: 0.000829
# Train mean square error: 0.000218811
# Test mean square error: 0.000778388
# Cost after epoch 9500: 0.000802
# Train mean square error: 8.75828e-05
# Test mean square error: 0.000631944
# Cost after epoch 9600: 0.000729
# Train mean square error: 8.48552e-05
# Test mean square error: 0.000660353
# Cost after epoch 9700: 0.000719
# Train mean square error: 0.000101935
# Test mean square error: 0.00066339
# Cost after epoch 9800: 0.000753
# Train mean square error: 0.000155153
# Test mean square error: 0.000734507
# Cost after epoch 9900: 0.000784
# Train mean square error: 0.000118656
# Test mean square error: 0.000628033
# Cost after epoch 10000: 0.000817
# Train mean square error: 0.000107727
# Test mean square error: 0.000621752
# Cost after epoch 10100: 0.000907
# Train mean square error: 0.000120061
# Test mean square error: 0.000707893
# Cost after epoch 10200: 0.000784
# Train mean square error: 0.00010798
# Test mean square error: 0.000685861
# Cost after epoch 10300: 0.000776
# Train mean square error: 0.000145533
# Test mean square error: 0.000717293
# Cost after epoch 10400: 0.000769
# Train mean square error: 0.000149908
# Test mean square error: 0.00076583
# Cost after epoch 10500: 0.000750
# Train mean square error: 8.26596e-05
# Test mean square error: 0.000663465
# Cost after epoch 10600: 0.000847
# Train mean square error: 0.000173104
# Test mean square error: 0.000774414
# Cost after epoch 10700: 0.000700
# Train mean square error: 9.91783e-05
# Test mean square error: 0.000707378
# Cost after epoch 10800: 0.000742
# Train mean square error: 8.02356e-05
# Test mean square error: 0.000650742
# Cost after epoch 10900: 0.000752
# Train mean square error: 7.68639e-05
# Test mean square error: 0.000673811
# Cost after epoch 11000: 0.000735
# Train mean square error: 0.000114405
# Test mean square error: 0.000704923
# Cost after epoch 11100: 0.000717
# Train mean square error: 0.000102918
# Test mean square error: 0.00068664
# Cost after epoch 11200: 0.000711
# Train mean square error: 9.74531e-05
# Test mean square error: 0.000671872
# Cost after epoch 11300: 0.000835
# Train mean square error: 0.000113838
# Test mean square error: 0.000697919
# Cost after epoch 11400: 0.000738
# Train mean square error: 8.87298e-05
# Test mean square error: 0.000635246
# Cost after epoch 11500: 0.000767
# Train mean square error: 0.000165267
# Test mean square error: 0.000682394
# Cost after epoch 11600: 0.000822
# Train mean square error: 8.45397e-05
# Test mean square error: 0.00068899
# Cost after epoch 11700: 0.000754
# Train mean square error: 0.000125391
# Test mean square error: 0.000734419
# Cost after epoch 11800: 0.000800
# Train mean square error: 7.51498e-05
# Test mean square error: 0.000631741
# Cost after epoch 11900: 0.000767
# Train mean square error: 0.000120076
# Test mean square error: 0.000696049
# Cost after epoch 12000: 0.000751
# Train mean square error: 0.000109517
# Test mean square error: 0.000706981
# Cost after epoch 12100: 0.000768
# Train mean square error: 0.000111892
# Test mean square error: 0.000679175
# Cost after epoch 12200: 0.000832
# Train mean square error: 0.000133382
# Test mean square error: 0.000667654
# Cost after epoch 12300: 0.000723
# Train mean square error: 9.79523e-05
# Test mean square error: 0.000671729
# Cost after epoch 12400: 0.000763
# Train mean square error: 9.24635e-05
# Test mean square error: 0.000686915
# Cost after epoch 12500: 0.000752
# Train mean square error: 0.000128536
# Test mean square error: 0.000710181
# Cost after epoch 12600: 0.000777
# Train mean square error: 0.000101229
# Test mean square error: 0.000664643
# Cost after epoch 12700: 0.000778
# Train mean square error: 6.60671e-05
# Test mean square error: 0.000662611
# Cost after epoch 12800: 0.000795
# Train mean square error: 0.000114701
# Test mean square error: 0.000675427
# Cost after epoch 12900: 0.000792
# Train mean square error: 0.000133659
# Test mean square error: 0.000693258
# Cost after epoch 13000: 0.000751
# Train mean square error: 0.000117449
# Test mean square error: 0.000660694
# Cost after epoch 13100: 0.000809
# Train mean square error: 0.000182049
# Test mean square error: 0.000723418
# Cost after epoch 13200: 0.000765
# Train mean square error: 9.21191e-05
# Test mean square error: 0.000657099
# Cost after epoch 13300: 0.000747
# Train mean square error: 9.10266e-05
# Test mean square error: 0.000648378
# Cost after epoch 13400: 0.000728
# Train mean square error: 8.94168e-05
# Test mean square error: 0.000645408
# Cost after epoch 13500: 0.000731
# Train mean square error: 0.000101303
# Test mean square error: 0.000650706
# Cost after epoch 13600: 0.000721
# Train mean square error: 8.18436e-05
# Test mean square error: 0.000689503
# Cost after epoch 13700: 0.000793
# Train mean square error: 0.000103015
# Test mean square error: 0.000651861
# Cost after epoch 13800: 0.000743
# Train mean square error: 7.80014e-05
# Test mean square error: 0.000661195
# Cost after epoch 13900: 0.000694
# Train mean square error: 0.000152853
# Test mean square error: 0.000812896
# Cost after epoch 14000: 0.000792
# Train mean square error: 6.38842e-05
# Test mean square error: 0.000658072
# Cost after epoch 14100: 0.000711
# Train mean square error: 7.81133e-05
# Test mean square error: 0.00068559
# Cost after epoch 14200: 0.000703
# Train mean square error: 0.000119592
# Test mean square error: 0.000726183
# Cost after epoch 14300: 0.000739
# Train mean square error: 0.000118784
# Test mean square error: 0.000751444
# Cost after epoch 14400: 0.000837
# Train mean square error: 0.000101259
# Test mean square error: 0.000684569
# Cost after epoch 14500: 0.000710
# Train mean square error: 6.67868e-05
# Test mean square error: 0.000705415
# Cost after epoch 14600: 0.000736
# Train mean square error: 0.000104629
# Test mean square error: 0.000689016
# Cost after epoch 14700: 0.000728
# Train mean square error: 7.28312e-05
# Test mean square error: 0.000668437
# Cost after epoch 14800: 0.000760
# Train mean square error: 9.14383e-05
# Test mean square error: 0.000636944
# Cost after epoch 14900: 0.000804
# Train mean square error: 7.80377e-05
# Test mean square error: 0.000678305
# Cost after epoch 15000: 0.000722
# Train mean square error: 8.251e-05
# Test mean square error: 0.000700479
# Cost after epoch 15100: 0.000742
# Train mean square error: 0.000121945
# Test mean square error: 0.000667093
# Cost after epoch 15200: 0.000726
# Train mean square error: 7.50191e-05
# Test mean square error: 0.000672517
# Cost after epoch 15300: 0.000797
# Train mean square error: 0.000120481
# Test mean square error: 0.000658505
# Cost after epoch 15400: 0.000748
# Train mean square error: 6.95808e-05
# Test mean square error: 0.000638903
# Cost after epoch 15500: 0.000794
# Train mean square error: 8.74985e-05
# Test mean square error: 0.000675135
# Cost after epoch 15600: 0.000693
# Train mean square error: 0.000110711
# Test mean square error: 0.00071227
# Cost after epoch 15700: 0.000816
# Train mean square error: 7.85101e-05
# Test mean square error: 0.000691197
# Cost after epoch 15800: 0.000765
# Train mean square error: 7.47037e-05
# Test mean square error: 0.000665784
# Cost after epoch 15900: 0.000694
# Train mean square error: 9.62318e-05
# Test mean square error: 0.000685329
# Cost after epoch 16000: 0.000724
# Train mean square error: 0.000121664
# Test mean square error: 0.000680321
# Cost after epoch 16100: 0.000680
# Train mean square error: 8.64027e-05
# Test mean square error: 0.00068223
# Cost after epoch 16200: 0.000825
# Train mean square error: 9.31752e-05
# Test mean square error: 0.00063121
# Cost after epoch 16300: 0.000750
# Train mean square error: 7.94918e-05
# Test mean square error: 0.000638537
# Cost after epoch 16400: 0.000697
# Train mean square error: 0.000152487
# Test mean square error: 0.000711443
# Cost after epoch 16500: 0.000808
# Train mean square error: 0.000118571
# Test mean square error: 0.000731753
# Cost after epoch 16600: 0.000728
# Train mean square error: 6.81026e-05
# Test mean square error: 0.000667484
# Cost after epoch 16700: 0.000742
# Train mean square error: 0.0001778
# Test mean square error: 0.000782852
# Cost after epoch 16800: 0.000844
# Train mean square error: 9.77966e-05
# Test mean square error: 0.000713821
# Cost after epoch 16900: 0.000748
# Train mean square error: 8.33777e-05
# Test mean square error: 0.000629336
# Cost after epoch 17000: 0.000713
# Train mean square error: 8.65296e-05
# Test mean square error: 0.000676143
# Cost after epoch 17100: 0.000693
# Train mean square error: 0.000102432
# Test mean square error: 0.000691371
# Cost after epoch 17200: 0.000727
# Train mean square error: 8.13619e-05
# Test mean square error: 0.000685285
# Cost after epoch 17300: 0.000690
# Train mean square error: 7.79489e-05
# Test mean square error: 0.000709364
# Cost after epoch 17400: 0.000701
# Train mean square error: 6.26846e-05
# Test mean square error: 0.000685002
# Cost after epoch 17500: 0.000749
# Train mean square error: 8.32968e-05
# Test mean square error: 0.000742509
# Cost after epoch 17600: 0.000777
# Train mean square error: 9.10105e-05
# Test mean square error: 0.000696902
# Cost after epoch 17700: 0.000782
# Train mean square error: 0.000107604
# Test mean square error: 0.000769972
# Cost after epoch 17800: 0.000778
# Train mean square error: 0.000135061
# Test mean square error: 0.000783737
# Cost after epoch 17900: 0.000717
# Train mean square error: 8.52111e-05
# Test mean square error: 0.000686214
# Cost after epoch 18000: 0.000796
# Train mean square error: 7.32868e-05
# Test mean square error: 0.00069303
# Cost after epoch 18100: 0.000715
# Train mean square error: 0.000100374
# Test mean square error: 0.000746773
# Cost after epoch 18200: 0.000641
# Train mean square error: 8.36032e-05
# Test mean square error: 0.000667938
# Cost after epoch 18300: 0.000856
# Train mean square error: 0.000108536
# Test mean square error: 0.00076714
# Cost after epoch 18400: 0.000735
# Train mean square error: 9.74537e-05
# Test mean square error: 0.000706753
# Cost after epoch 18500: 0.000701
# Train mean square error: 0.000135493
# Test mean square error: 0.000680187
# Cost after epoch 18600: 0.000724
# Train mean square error: 6.30072e-05
# Test mean square error: 0.000687902
# Cost after epoch 18700: 0.000834
# Train mean square error: 8.46041e-05
# Test mean square error: 0.000670862
# Cost after epoch 18800: 0.000804
# Train mean square error: 6.43518e-05
# Test mean square error: 0.000675947
# Cost after epoch 18900: 0.000759
# Train mean square error: 0.000156028
# Test mean square error: 0.000810288
# Cost after epoch 19000: 0.000755
# Train mean square error: 7.2872e-05
# Test mean square error: 0.000669866
# Cost after epoch 19100: 0.000713
# Train mean square error: 8.05916e-05
# Test mean square error: 0.000733497
# Cost after epoch 19200: 0.000752
# Train mean square error: 7.06389e-05
# Test mean square error: 0.00069299
# Cost after epoch 19300: 0.000714
# Train mean square error: 9.25037e-05
# Test mean square error: 0.000694587
# Cost after epoch 19400: 0.000870
# Train mean square error: 8.70173e-05
# Test mean square error: 0.000708192
# Cost after epoch 19500: 0.000744
# Train mean square error: 8.47575e-05
# Test mean square error: 0.000668523
# Cost after epoch 19600: 0.000677
# Train mean square error: 0.000139523
# Test mean square error: 0.000756912
# Cost after epoch 19700: 0.000738
# Train mean square error: 0.000115301
# Test mean square error: 0.000718854
# Cost after epoch 19800: 0.000756
# Train mean square error: 0.000256594
# Test mean square error: 0.00085482
# Cost after epoch 19900: 0.000747
# Train mean square error: 0.000157853
# Test mean square error: 0.000808174
# Trained model has been saved.
# Train mean square error: 8.15898e-05
# Test mean square error: 0.000719856

# %%
tf.reset_default_graph()
keep_prob, x, y_, y, cost, optimizer = build_graph(learning_rate=1e-4)
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    saver = tf.train.Saver()
    saver.restore(sess, '.\mc_regr_cnn\model\model_3')
    print ("Train mean square error:", sess.run(cost,feed_dict={keep_prob: 1, x: X_train, y_: Y_train}))
    print ("Test mean square error:", sess.run(cost,feed_dict={keep_prob: 1, x: X_test, y_: Y_test}))
# Out:
# INFO:tensorflow:Restoring parameters from .\mc_regr_cnn\model\model_3
# Train mean square error: 8.15898e-05
# Test mean square error: 0.000719856
